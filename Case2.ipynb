# %%
from pyomo.environ import * 
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import folium 
from folium.plugins import AntPath


# Cambiar las rutas de los archivos
clients = pd.read_csv(r'case_2_cost\Clients.csv')  # Clientes
depots = pd.read_csv(r'case_2_cost\Depots.csv')    # Depósitos
distancias = pd.read_csv(r'Matrices/distancias2.csv')  # Matriz de distancias
tiempos = pd.read_csv(r'Matrices/tiempos2.csv')        # Matriz de tiempos
vehicles = pd.read_csv(r'case_2_cost\Vehicles.csv')    # Vehículos
costos_operativos = pd.read_csv(r'case_2_costs_vehicules\costos_operativos_combinados2.csv')   # Costos Operativos 



# Daily Maintenance [COP/day]
costos_mantenimiento = {
    'V1': 30000,
    'V2': 30000,
    'V3': 21000,
    'V4': 21000,
    'V5': 3000,
    'V6': 3000,
}

costos_mantenimiento_total = sum(costos_mantenimiento.values())





vehicles['ID'] = ['V' + str(i+1) for i in range(len(vehicles))]

# Crear conjuntos
distancias_dict = {(int(row["Desde"]+1), int(row["Hacia"]+1)): row["Distancia"] for _, row in distancias.iterrows()}


clientes = clients['LocationID'].tolist()  # IDs de los clientes
centros = depots['LocationID'].tolist()   # IDs de los depósitos
vehiculos = vehicles['ID'].tolist()  # IDs de los vehículos
nodos = centros + clientes  # Todos los nodos (clientes + depósitos)
clients.columns = clients.columns.str.strip()
depots.columns = depots.columns.str.strip()
productos={}
# Crear parámetros
# 1. Demandas de clientes por producto (puede venir de Clients.csv o ser constante)
demandas_clients = {(row['LocationID']): row['Product'] for _, row in clients.iterrows() }




# 2. Capacidades de los vehículos (Vehicles.csv)
capacidad_vehiculo = {row['ID']: row['Capacity'] for _, row in vehicles.iterrows()}

# 3. Rango máximo de los vehículos (Vehicles.csv)
rango_vehiculo = {row['ID']: row['Range']*1000 for _, row in vehicles.iterrows()}
print(rango_vehiculo)
# 4. Costo operativo 
costos_operativos_dict = {(row['Vehiculo'], row['Desde'], row['Hacia']): row['Costo'] 
                          for _, row in costos_operativos.iterrows()}



# 6. Capacidades de los centros de distribución (Depots.csv)
#capacidades_centro = {(row['DepotID'], p): row[f'Capacidad_{p}'] for _, row in depots.iterrows() for p in productos}

# 7. Distancias y tiempos (distancias1.csv y tiempos1.csv)
# Convertir archivos CSV a diccionarios

tiempos_dict = {(row['Desde'], row['Hacia']): row['Tiempo'] for _, row in tiempos.iterrows()}
# Crear diccionario de coordenadas para todos los nodos
all_coords = {
    **{row['LocationID']: (row['Latitude'], row['Longitude']) for _, row in clients.iterrows()},
    **{row['LocationID']: (row['Latitude'], row['Longitude']) for _, row in depots.iterrows()}
}


# Validar dimensiones
print(f"Clientes: {len(clientes)}, Centros: {len(centros)}, Vehículos: {len(vehiculos)}, Nodos: {len(nodos)}")
# Out:
# {'V1': 145852.07096486446, 'V2': 195690.8956922408, 'V3': 953172.608610164, 'V4': 1153486.9458305817, 'V5': 16627.680130757893, 'V6': 13602.810739289229}
# Clientes: 30, Centros: 12, Vehículos: 6, Nodos: 42

# %%
class VRPModel:
    def __init__(self, clientes, centros, vehiculos, productos, distancias_dict, tiempos, demandas, capacidad_vehiculo, rango_vehiculo, costos_operativos_dict, costos_mantenimiento,all_coords):
        """
        Inicializar parámetros del modelo VRP.
        """
        # Conjuntos y parámetros
        self.clientes = clientes
        self.centros = centros
        self.vehiculos = vehiculos
        self.productos = productos
        self.nodos = clientes + centros
        self.distancias_dict = distancias_dict
        self.tiempos = tiempos
        self.demandas = demandas
        self.capacidad_vehiculo = capacidad_vehiculo
        self.rango_vehiculo = rango_vehiculo
        self.costos_operativos_dict= costos_operativos_dict
        self.costos_mantenimiento = costos_mantenimiento
        self.all_coords = all_coords

        
        
        # Crear modelo Pyomo
        self.model = ConcreteModel()

    def build_model(self):
        """
        Construir el modelo de optimización.
        """
        model = self.model

        # Sets
        model.C = Set(initialize=self.clientes)
        model.D = Set(initialize=self.centros)
        model.V = Set(initialize=self.vehiculos)
        model.P = Set(initialize=self.productos)
        model.N = Set(initialize=self.nodos) 

        # Variables
        model.x = Var(model.N, model.N, model.V, within=Binary)  # Ruta del vehículo
        model.z = Var(model.V, within=Binary)  # Activación del vehículo
        model.q = Var(model.N, model.V, within=NonNegativeReals)  # Carga transportada

        # Función objetivo: Minimizar costos
        def obj_expression(model):
            return sum(
                # Costos por distancia
                model.x[i, j, v] * costos_operativos_dict[(v, i, j)]
                for v in model.V for i in model.N for j in model.N if (v, i, j) in costos_operativos_dict) + costos_mantenimiento_total
            
        model.obj = Objective(rule=obj_expression, sense=minimize)
        
        # Restricciones

        # 1. Cada cliente debe ser visitado exactamente una vez
        def restriccion_visita_unica(model, i):
            return sum(model.x[i, j, v] for j in model.N for v in model.V if i != j) == 1
        model.restriccion_visita_unica = Constraint(model.C, rule=restriccion_visita_unica)

        # 2. Conservación del flujo en los nodos
        def restriccion_flujo(model, i, v):
            return sum(model.x[i, j, v] for j in model.N if i != j) == sum(model.x[j, i, v] for j in model.N if i != j)
        model.restriccion_flujo = Constraint(model.N, model.V, rule=restriccion_flujo)

        # 3. Capacidad de los vehículos
        def restriccion_capacidad_vehiculo(model, v):
            return sum(model.q[i, v] for i in model.C) <= self.capacidad_vehiculo[v]
        model.restriccion_capacidad_vehiculo = Constraint(model.V, rule=restriccion_capacidad_vehiculo)

        #4. No viajes a si mismo
        def restriccion_no_viajes(model, i, v):
            return model.x[i, i, v] == 0
        model.restriccion_no_viajes = Constraint(model.N, model.V, rule=restriccion_no_viajes)
        
        #5. No viaaje de un deposito a otro deposito
        def restriccion_no_viajes_centros(model, i, j, v):
            return model.x[i, j, v] == 0
        model.restriccion_no_viajes_centros = Constraint(model.D, model.D, model.V, rule=restriccion_no_viajes_centros)
        

        # 6. Límite de rango de los vehículos
        def restriccion_rango_vehiculo(model, v):
            return sum(self.distancias_dict[(i, j)] * model.x[i, j, v] for i in model.N for j in model.N if i != j) <= self.rango_vehiculo[v]
        model.restriccion_rango_vehiculo = Constraint(model.V, rule=restriccion_rango_vehiculo)
        
        

        #7. Restricción de activación de vehículos
        M= len(self.nodos)
        def restriccion_activacion_vehiculo(model, v):
            return sum(model.x[i, j, v] for i in model.N for j in model.N if i != j) <= M * model.z[v]
        model.restriccion_activacion_vehiculo = Constraint(model.V, rule=restriccion_activacion_vehiculo)

        # 8. Eliminación de subtours (MTZ)
        model.u = Var(model.N, model.V, within=NonNegativeReals)
        def restriccion_subtours(model, i, j, v):
            if i != j:
                return model.u[i, v] - model.u[j, v] + len(model.N) * model.x[i, j, v] <= len(model.N) - 1
            return Constraint.Skip
        model.restriccion_subtours = Constraint(model.C, model.C, model.V, rule=restriccion_subtours)

        #9. Sale de un centro depot
        def restriccion_sale_vehiculo(model,v):
            return sum(model.x[d,j,v] for d in model.D for j in model.N)==1
        model.restriccion_sale_vehiculo= Constraint(model.V, rule= restriccion_sale_vehiculo)
        
        def restriccion_entra_vehiculo(model,v):
            return sum(model.x[i,d,v] for d in model.D for i in model.N)==1
        model.restriccion_entra_vehiculo= Constraint(model.V, rule= restriccion_entra_vehiculo)
        
        return model
    

    
    
    def solve_model(self):
        """
        Resolver el modelo utilizando HiGHS.
        """
        solver_name = "appsi_highs"
        solver = SolverFactory(solver_name)
        solver.options['parallel'] = 'on'
        solver.options['time_limit'] = 5*60  # 1-hour time limit
        solver.options['presolve'] = 'on'
        solver.options['mip_rel_gap'] = 0.01  # 1% relative gap
        solver.options['simplex_strategy'] = 1  # Dual simplex
        solver.options['simplex_max_concurrency'] = 8  # Max concurrency
        solver.options['mip_min_logging_interval'] = 10  # Log every 10 seconds
        solver.options['mip_heuristic_effort'] = 0.2  # Increase heuristic effort

        # Resolver el modelo
        result = solver.solve(self.model, tee=True)

        # Verificar el estado del solver
        if result.solver.termination_condition == TerminationCondition.infeasible:
            print("El modelo es infactible.")
        elif result.solver.termination_condition == TerminationCondition.optimal:
            print("Se encontró una solución óptima.")
            # Cargar la solución si es óptima
            self.model.solutions.load_from(result)
        elif result.solver.termination_condition == TerminationCondition.unbounded:
            print("El modelo es no acotado.")
        elif result.solver.termination_condition == TerminationCondition.maxTimeLimit:
            print("Se alcanzó el límite de tiempo.")
        else:
            print(f"Condición de terminación desconocida: {result.solver.termination_condition}")

        print(result)

        
    def display_results(self):
        print("\nRutas asignadas por vehículo:")
        for v in self.vehiculos:
            print(f"Vehículo: {v}")
            for i in self.nodos:
                for j in self.nodos:
                    if i != j and round(value(self.model.x[i, j, v])) == 1:  # Redondeamos el valor
                        print(f"   De {i} a {j}")
                        

    def visualize_routes_with_map(self):
        selected_routes = []
        for v in self.vehiculos:
            routes_for_v = [
                (i, j) for i in self.nodos for j in self.nodos
                if i != j and round(value(self.model.x[i, j, v])) == 1
            ]
            print(f"Rutas seleccionadas para el vehículo {v}: {routes_for_v}")
            selected_routes.append(routes_for_v)

        # Preparar colores y nodos
        colors = ['green', 'orange', 'darkblue', 'darkred', 'red', 'purple', 'black']
        node_colors = {}
        for k in range(len(self.vehiculos)):
            for route in selected_routes[k]:
                i, j = route
                idx_color = k % len(colors)
                if i not in node_colors and i > len(self.centros):
                    node_colors[i] = colors[idx_color]
                if j not in node_colors and j > len(self.centros):
                    node_colors[j] = colors[idx_color]

        # Crear el mapa
        mapa = folium.Map(location=all_coords[self.centros[0]], zoom_start=12)
        for idx in all_coords:
            lat, lon = all_coords[idx]
            icon, color = ("warehouse", 'gray') if idx in self.centros else ("envelope", node_colors.get(idx, "black"))

            folium.Marker(
                location=(lat, lon),
                popup=f"Nodo {idx}",
                icon=folium.Icon(color=color, icon=icon, prefix="fa"),
            ).add_to(mapa)

        for k in range(len(self.vehiculos)):
            for route in selected_routes[k]:
                i, j = route
                idx_color = k % len(colors)

                AntPath(
                    locations=[all_coords[i], all_coords[j]],
                    tooltip=f"Vehículo {self.vehiculos[k]}: {i} -> {j}",
                    color=colors[idx_color],
                ).add_to(mapa)

        # Guardar el mapa
        mapa.save("mapa_rutas_optimizadas.html")
        print("Mapa guardado como mapa_rutas_optimizadas.html")
        return mapa
    
    def exportar_rutas_a_csv(self, archivo_csv="rutas_asignadas.csv"):
        """
        Exporta las rutas asignadas por vehículo a un archivo CSV.
        
        Parámetros:
            archivo_csv (str): Nombre del archivo CSV de salida.
        """
        rutas = []

        # Recolectar las rutas asignadas
        for v in self.vehiculos:
            for i in self.nodos:
                for j in self.nodos:
                    if i != j and round(value(self.model.x[i, j, v])) == 1:  # Ruta activa
                        rutas.append({
                            "Vehículo": v,
                            "Origen": i,
                            "Destino": j
                        })

        # Crear un DataFrame de pandas con las rutas
        df_rutas = pd.DataFrame(rutas)

        # Exportar a CSV
        df_rutas.to_csv(archivo_csv, index=False)
        print(f"Rutas exportadas a {archivo_csv}")

# %%
# Instanciar la clase del modelo
vrp = VRPModel(
    clientes=clientes,
    centros=centros,
    vehiculos=vehiculos,
    productos=productos,
    distancias_dict=distancias_dict,
    tiempos=tiempos,
    demandas=demandas_clients,
    capacidad_vehiculo=capacidad_vehiculo,
    rango_vehiculo=rango_vehiculo,
    costos_operativos_dict=costos_operativos_dict,
    costos_mantenimiento=costos_mantenimiento,
    all_coords=all_coords
)

# Construir el modelo
vrp.build_model()

# Resolver el modelo
vrp.solve_model()

vrp.display_results()

vrp.visualize_routes_with_map()
# Out:
# Running HiGHS 1.8.1 (git hash: 4a7f24a): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 4e+04]
#   Cost   [8e+02, 2e+05]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+06]
# Presolving model
# 5526 rows, 8347 cols, 57588 nonzeros  0s
# 5027 rows, 7633 cols, 49430 nonzeros  7s
#
# Solving MIP model with:
#    5027 rows
#    7633 cols (7453 binary, 0 integer, 0 implied int., 180 continuous)
#    49430 nonzeros
# MIP-Timing:           9 - starting analytic centre calculation
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   108000          inf                  inf        0      0      0         0     9.0s
#          0       0         0   0.00%   427554.43354    inf                  inf        0      0      3       452     9.1s
#  L       0       0         0   0.00%   529886.541023   915110.783333     42.10%     1025    205     60      4744    42.9s
#          4       0         1  12.50%   529886.541023   915110.783333     42.10%     1031     79     97     12515    53.5s
#         20       1         8  23.14%   529886.541023   915110.783333     42.10%     1071     79   1054     31693    66.5s
#         34       1        15  23.43%   529886.541023   915110.783333     42.10%     1100     79   1750     45210    76.6s
#  B      59       1        19  23.43%   529886.541023   862417.65         38.56%     1115     79   2239     48383    79.5s
#         74      22        23  33.20%   530162.164693   862417.65         38.53%     1155     88   2911     65261    89.6s
#        131      47        37  33.24%   530192.374112   862417.65         38.52%     1375    160   5319     87502   111.8s
#  L     163      25        45  33.30%   530192.374112   697622.55         24.00%     1380    145   6519     91443   125.6s
#        186      36        49  40.33%   530192.374112   697622.55         24.00%     1339    166   7964    119163   150.4s
#        252      48        74  42.39%   532064.788806   697622.55         23.73%     1431    147   9308    135790   172.6s
#        322      50       107  42.54%   532064.788806   697622.55         23.73%     1456    147   9146    146419   182.7s
#        349      54       120  42.66%   532064.788806   697622.55         23.73%     1453    169   9590    156841   198.9s
#        458      77       161  42.71%   532064.788806   697622.55         23.73%     1506    196   9660    169270   210.1s
#        595      96       212  43.32%   549769.112279   697622.55         21.19%     1798    179   8347    179211   220.5s
#        739     124       266  44.04%   551397.592907   697622.55         20.96%     2050    228   9206    197992   242.7s
#        886     162       316  46.53%   554842.913478   697622.55         20.47%     2197    211   9318    209788   252.7s
#        951     178       340  47.05%   554842.913478   697622.55         20.47%     2140    285   9443    218568   269.0s
#       1074     191       390  47.78%   554842.913478   697622.55         20.47%     2126    222   9894    233011   289.8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#       1223     211       450  48.48%   555014.550634   697622.55         20.44%     2041    227   8748    246844   299.8s
#       1224     211       451  48.48%   555014.550634   697622.55         20.44%     2059    244   8985    250687   302.5s
#
# Solving report
#   Status            Time limit reached
#   Primal bound      697622.55
#   Dual bound        555014.550634
#   Gap               20.44% (tolerance: 1%)
#   P-D integral      72.5829025448
#   Solution status   feasible
#                     697622.55 (objective)
#                     0 (bound viol.)
#                     9.99200722163e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            302.53 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 8
#   Nodes             1224
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     250687 (total)
#                     136065 (strong br.)
#                     5459 (separation)
#                     41452 (heuristics)
# WARNING: Loading a feasible but suboptimal solution. Please set
# load_solution=False and check results.termination_condition and
# results.found_feasible_solution() before loading a solution.
# Se alcanzó el límite de tiempo.
#
# Problem:
# - Lower bound: 555014.550634301
#   Upper bound: 697622.5499999999
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 0
#   Sense: minimize
# Solver:
# - Status: aborted
#   Termination condition: maxTimeLimit
#   Termination message: TerminationCondition.maxTimeLimit
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#
# Rutas asignadas por vehículo:
# Vehículo: V1
#    De 26 a 3
#    De 3 a 26
# Vehículo: V2
#    De 22 a 7
#    De 7 a 22
# Vehículo: V3
#    De 16 a 1
#    De 1 a 16
# Vehículo: V4
#    De 13 a 35
#    De 14 a 13
#    De 15 a 14
#    De 18 a 36
#    De 19 a 33
#    De 20 a 21
#    De 21 a 32
#    De 23 a 25
#    De 24 a 28
#    De 25 a 18
#    De 28 a 41
#    De 29 a 38
#    De 30 a 20
#    De 32 a 42
#    De 33 a 29
#    De 34 a 24
#    De 35 a 34
#    De 36 a 40
#    De 37 a 19
#    De 38 a 30
#    De 40 a 37
#    De 41 a 7
#    De 42 a 15
#    De 7 a 23
# Vehículo: V5
#    De 27 a 31
#    De 31 a 39
#    De 39 a 4
#    De 4 a 27
# Vehículo: V6
#    De 17 a 9
#    De 9 a 17
# Rutas seleccionadas para el vehículo V1: [(26, 3), (3, 26)]
# Rutas seleccionadas para el vehículo V2: [(22, 7), (7, 22)]
# Rutas seleccionadas para el vehículo V3: [(16, 1), (1, 16)]
# Rutas seleccionadas para el vehículo V4: [(13, 35), (14, 13), (15, 14), (18, 36), (19, 33), (20, 21), (21, 32), (23, 25), (24, 28), (25, 18), (28, 41), (29, 38), (30, 20), (32, 42), (33, 29), (34, 24), (35, 34), (36, 40), (37, 19), (38, 30), (40, 37), (41, 7), (42, 15), (7, 23)]
# Rutas seleccionadas para el vehículo V5: [(27, 31), (31, 39), (39, 4), (4, 27)]
# Rutas seleccionadas para el vehículo V6: [(17, 9), (9, 17)]
# Mapa guardado como mapa_rutas_optimizadas.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1eda052eecb5e90ec02f79553907de12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1eda052eecb5e90ec02f79553907de12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1eda052eecb5e90ec02f79553907de12 = L.map(
#                 &quot;map_1eda052eecb5e90ec02f79553907de12&quot;,
#                 {
#                     center: [4.75021190869025, -74.08124218159384],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d60630632ca6741ed8c6197373716f20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d60630632ca6741ed8c6197373716f20.addTo(map_1eda052eecb5e90ec02f79553907de12);
#
#
#             var marker_59775ceb2a59bf88c12ab5843cc807df = L.marker(
#                 [4.683166312717828, -74.11818856236133],
#                 {}
#             ).addTo(map_1eda052eecb5e90ec02f79553907de12);
#
#
#             var icon_fc2a490f8aec88a9867fb15ef1a6aec2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;envelope&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_59775ceb2a59bf88c12ab5843cc807df.setIcon(icon_fc2a490f8aec88a9867fb15ef1a6aec2);
#
#
#         var popup_565ec36148e064f4dcfdf7b4c7359f2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d9fefbe063f3c51be7661fc3da1edfd = $(`&lt;div id=&quot;html_1d9fefbe063f3c51be7661fc3da1edfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nodo 13.0&lt;/div&gt;`)[0];
#                 popup_565ec36148e064f4dcfdf7b4c7359f2f.setContent(html_1d9fefbe063f3c51be7661fc3da1edfd);
#
#
#
#         marker_59775ceb2a59bf88c12ab5843cc807df.bindPopup(popup_565ec36148e064f4dcfdf7b4c7359f2f)
#         ;
#
#
#
#
#             var marker_a5f83e9aa1807d0d437a051792c4e6d7 = L.marker(
#                 [4.709506141183739, -74.09614643132555],
#                 {}
#             ).addTo(map_1eda052eecb5e90ec02f79553907de12);
#
#
#             var icon_20a33261fb47417108b8367ff5a5c0e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;envelope&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a5f83e9aa1807d0d437a051792c4e6d7.setIcon(icon_20a33261fb47417108b8367ff5a5c0e8);
#
#
#         var popup_3f0b740c1739d44ceaccf9e9c67aa94b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8db02b337803642e479e404b91fc26cb = $(`&lt;div id=&quot;html_8db02b337803642e479e404b91fc26cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nodo 14.0&lt;/div&gt;`)[0];
#                 popup_3f0b740c1739d44ceaccf9e9c67aa94b.setContent(html_8db02b337803642e479e404b91fc26cb);
#
#
#
#         marker_a5f83e9aa1807d0d437a051792c4e6d7.bindPopup(popup_3f0b740c1739d44ceaccf9e9c67aa94b)
#         ;
#
#
#
#
#             var marker_c43cb50a8ccfcb8abd1bc6f9aafdfe23 = L.marker(
#                 [4.727898892788284, -74.11733099443472],
#                 {}
#             ).addTo(map_1eda052eecb5e90ec02f79553907de12);
#
#
#             var icon_9a238b2c219ee5e8d2f37a4f1cfff1db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;envelope&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c43cb50a8ccfcb8abd1bc6f9aafdfe23.setIcon(icon_9a238b2c219ee5e8d2f37a4f1cfff1db);
#
#
#         var popup_adb6e41bd63a081a0fea228e2cea0bb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d183709f782c37ef20ac07aad08f162c = $(`&lt;div id=&quot;html_d183709f782c37ef20ac07aad08f162c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nodo 15.0&lt;/div&gt;`)[0];
#                 popup_adb6e41bd63a081a0fea228e2cea0bb2.setContent(html_d183709f782c37ef20ac07aad08f162c);
#
#
#
#         marker_c43cb50a8ccfcb8abd1bc6f9aafdfe23.bindPopup(popup_adb6e41bd63a081a0fea228e2cea0bb2)
#         ;
#
#
#
#
#             var marker_637c7b6df0f39cdf45dcb19b61083437 = L.marker(
#                 [4.762362666148266, -74.06168478791987],
#                 {}
#             ).addTo(map_1eda052eecb5e90ec02f79553907de12);
#
#
#             var icon_653d5e8a2b30b16cfd07b29e8

# %%
vrp.model.display()
# Out:
# Model unknown
#
#   Variables:
#     x : Size=10584, Index=N*N*V
#         Key            : Lower : Value                  : Upper : Fixed : Stale : Domain
#           (1, 1, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 1, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 1, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 1, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 1, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 1, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 2, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 2, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 2, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 2, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 2, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 2, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 3, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 3, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 3, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 3, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 3, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 3, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 4, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 4, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 4, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 4, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 4, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 4, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 5, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 5, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 5, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 5, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 5, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 5, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 6, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 6, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 6, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 6, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 6, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 6, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 7, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 7, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 7, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 7, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 7, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 7, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 8, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 8, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 8, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 8, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 8, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 8, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 9, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 9, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 9, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 9, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 9, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (1, 9, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 10, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 10, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 10, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 10, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 10, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 10, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 11, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 11, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 11, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 11, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 11, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 11, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 12, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 12, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 12, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 12, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 12, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 12, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 13, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 13, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 13, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 13, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 13, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 13, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 14, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 14, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 14, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 14, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 14, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 14, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 15, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 15, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 15, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 15, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 15, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 15, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 16, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 16, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 16, 'V3') :     0 :                    1.0 :     1 : False : False : Binary
#          (1, 16, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 16, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 16, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 17, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 17, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 17, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 17, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 17, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 17, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 18, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 18, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 18, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 18, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 18, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 18, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 19, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 19, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 19, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 19, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 19, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 19, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 20, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 20, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 20, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 20, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 20, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 20, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 21, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 21, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 21, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 21, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 21, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 21, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 22, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 22, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 22, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 22, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 22, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 22, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 23, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 23, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 23, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 23, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 23, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 23, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 24, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 24, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 24, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 24, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 24, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 24, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 25, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 25, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 25, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 25, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 25, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 25, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 26, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 26, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 26, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 26, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 26, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 26, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 27, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 27, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 27, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 27, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 27, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 27, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 28, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 28, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 28, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 28, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 28, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 28, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 29, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 29, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 29, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 29, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 29, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 29, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 30, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 30, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 30, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 30, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 30, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 30, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 31, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 31, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 31, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 31, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 31, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 31, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 32, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 32, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 32, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 32, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 32, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 32, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 33, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 33, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 33, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 33, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 33, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 33, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 34, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 34, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 34, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 34, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 34, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 34, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 35, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 35, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 35, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 35, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 35, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 35, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 36, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 36, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 36, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 36, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 36, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 36, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 37, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 37, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 37, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 37, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 37, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 37, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 38, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 38, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 38, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 38, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 38, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 38, 'V6') :     0 :  3.383536836952858e-16 :     1 : False : False : Binary
#          (1, 39, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 39, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 39, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 39, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 39, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 39, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 40, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 40, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 40, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 40, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 40, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 40, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 41, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 41, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 41, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 41, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 41, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 41, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 42, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 42, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 42, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 42, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 42, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (1, 42, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 1, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 1, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 1, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 1, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 1, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 1, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 2, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 2, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 2, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 2, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 2, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 2, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 3, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 3, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 3, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 3, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 3, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 3, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 4, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 4, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 4, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 4, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 4, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 4, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 5, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 5, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 5, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 5, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 5, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 5, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 6, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 6, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 6, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 6, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 6, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 6, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 7, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 7, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 7, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 7, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 7, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 7, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 8, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 8, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 8, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 8, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 8, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 8, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 9, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 9, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 9, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 9, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 9, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (2, 9, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 10, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 10, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 10, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 10, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 10, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 10, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 11, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 11, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 11, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 11, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 11, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 11, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 12, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 12, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 12, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 12, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 12, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 12, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 13, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 13, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 13, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 13, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 13, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 13, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 14, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 14, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 14, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 14, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 14, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 14, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 15, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 15, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 15, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 15, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 15, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 15, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 16, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 16, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 16, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 16, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 16, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 16, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 17, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 17, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 17, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 17, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 17, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 17, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 18, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 18, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 18, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 18, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 18, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 18, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 19, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 19, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 19, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 19, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 19, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 19, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 20, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 20, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 20, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 20, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 20, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 20, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 21, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 21, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 21, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 21, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 21, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 21, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 22, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 22, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 22, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 22, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 22, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 22, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 23, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 23, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 23, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 23, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 23, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 23, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 24, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 24, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 24, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 24, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 24, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 24, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 25, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 25, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 25, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 25, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 25, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 25, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 26, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 26, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 26, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 26, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 26, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 26, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 27, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 27, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 27, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 27, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 27, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 27, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 28, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 28, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 28, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 28, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 28, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 28, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 29, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 29, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 29, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 29, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 29, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 29, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 30, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 30, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 30, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 30, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 30, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 30, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 31, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 31, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 31, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 31, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 31, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 31, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 32, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 32, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 32, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 32, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 32, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 32, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 33, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 33, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 33, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 33, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 33, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 33, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 34, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 34, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 34, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 34, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 34, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 34, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 35, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 35, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 35, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 35, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 35, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 35, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 36, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 36, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 36, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 36, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 36, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 36, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 37, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 37, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 37, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 37, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 37, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 37, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 38, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 38, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 38, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 38, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 38, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 38, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 39, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 39, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 39, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 39, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 39, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 39, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 40, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 40, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 40, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 40, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 40, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 40, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 41, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 41, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 41, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 41, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 41, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 41, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 42, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 42, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 42, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 42, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 42, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#          (2, 42, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 1, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 1, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 1, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 1, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 1, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 1, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 2, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 2, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 2, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 2, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 2, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 2, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 3, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 3, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 3, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 3, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 3, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 3, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 4, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 4, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 4, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 4, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 4, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 4, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 5, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 5, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 5, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 5, 'V4') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 5, 'V5') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 5, 'V6') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 6, 'V1') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 6, 'V2') :     0 :                    0.0 :     1 : False : False : Binary
#           (3, 6, 'V3') :     0 :                    0.0 :     1 : False : False : Binary
# ...
#         (41, 31, 'V2') :  None :                    0.0 :  41.0
#         (41, 31, 'V3') :  None :                    0.0 :  41.0
#         (41, 31, 'V4') :  None :     21.999999999999883 :  41.0
#         (41, 31, 'V5') :  None :                   -1.0 :  41.0
#         (41, 31, 'V6') :  None :                    0.0 :  41.0
#         (41, 32, 'V1') :  None :                    0.0 :  41.0
#         (41, 32, 'V2') :  None :                    0.0 :  41.0
#         (41, 32, 'V3') :  None :                    0.0 :  41.0
#         (41, 32, 'V4') :  None :      8.999999999999911 :  41.0
#         (41, 32, 'V5') :  None :                    0.0 :  41.0
#         (41, 32, 'V6') :  None :                    0.0 :  41.0
#         (41, 33, 'V1') :  None :                    0.0 :  41.0
#         (41, 33, 'V2') :  None :                    0.0 :  41.0
#         (41, 33, 'V3') :  None :                    0.0 :  41.0
#         (41, 33, 'V4') :  None :      14.99999999999989 :  41.0
#         (41, 33, 'V5') :  None :                    0.0 :  41.0
#         (41, 33, 'V6') :  None :                    0.0 :  41.0
#         (41, 34, 'V1') :  None :                    0.0 :  41.0
#         (41, 34, 'V2') :  None :                    0.0 :  41.0
#         (41, 34, 'V3') :  None :                    0.0 :  41.0
#         (41, 34, 'V4') :  None :      2.999999999999922 :  41.0
#         (41, 34, 'V5') :  None :                    0.0 :  41.0
#         (41, 34, 'V6') :  None :                    0.0 :  41.0
#         (41, 35, 'V1') :  None :                    0.0 :  41.0
#         (41, 35, 'V2') :  None :                    0.0 :  41.0
#         (41, 35, 'V3') :  None :                    0.0 :  41.0
#         (41, 35, 'V4') :  None :      3.999999999999911 :  41.0
#         (41, 35, 'V5') :  None :                    0.0 :  41.0
#         (41, 35, 'V6') :  None :                    0.0 :  41.0
#         (41, 36, 'V1') :  None :                    0.0 :  41.0
#         (41, 36, 'V2') :  None :                    0.0 :  41.0
#         (41, 36, 'V3') :  None :                    0.0 :  41.0
#         (41, 36, 'V4') :  None :      18.99999999999989 :  41.0
#         (41, 36, 'V5') :  None :                    0.0 :  41.0
#         (41, 36, 'V6') :  None :                    0.0 :  41.0
#         (41, 37, 'V1') :  None :                    0.0 :  41.0
#         (41, 37, 'V2') :  None :                    0.0 :  41.0
#         (41, 37, 'V3') :  None :                    0.0 :  41.0
#         (41, 37, 'V4') :  None :     16.999999999999893 :  41.0
#         (41, 37, 'V5') :  None :                    0.0 :  41.0
#         (41, 37, 'V6') :  None :                    0.0 :  41.0
#         (41, 38, 'V1') :  None :                    0.0 :  41.0
#         (41, 38, 'V2') :  None :                    0.0 :  41.0
#         (41, 38, 'V3') :  None :                    0.0 :  41.0
#         (41, 38, 'V4') :  None :     12.999999999999911 :  41.0
#         (41, 38, 'V5') :  None :                    0.0 :  41.0
#         (41, 38, 'V6') :  None :                    0.0 :  41.0
#         (41, 39, 'V1') :  None :                    0.0 :  41.0
#         (41, 39, 'V2') :  None :                    0.0 :  41.0
#         (41, 39, 'V3') :  None :                    0.0 :  41.0
#         (41, 39, 'V4') :  None :     21.999999999999883 :  41.0
#         (41, 39, 'V5') :  None :                   -2.0 :  41.0
#         (41, 39, 'V6') :  None :                    0.0 :  41.0
#         (41, 40, 'V1') :  None :                    0.0 :  41.0
#         (41, 40, 'V2') :  None :                    0.0 :  41.0
#         (41, 40, 'V3') :  None :                    0.0 :  41.0
#         (41, 40, 'V4') :  None :      17.99999999999989 :  41.0
#         (41, 40, 'V5') :  None :                    0.0 :  41.0
#         (41, 40, 'V6') :  None :                    0.0 :  41.0
#         (41, 42, 'V1') :  None :                    0.0 :  41.0
#         (41, 42, 'V2') :  None :                    0.0 :  41.0
#         (41, 42, 'V3') :  None :                    0.0 :  41.0
#         (41, 42, 'V4') :  None :      7.999999999999911 :  41.0
#         (41, 42, 'V5') :  None :                    0.0 :  41.0
#         (41, 42, 'V6') :  None :                    0.0 :  41.0
#         (42, 13, 'V1') :  None :                    0.0 :  41.0
#         (42, 13, 'V2') :  None :                    0.0 :  41.0
#         (42, 13, 'V3') :  None :                    0.0 :  41.0
#         (42, 13, 'V4') :  None :                   -3.0 :  41.0
#         (42, 13, 'V5') :  None :                    0.0 :  41.0
#         (42, 13, 'V6') :  None :                    0.0 :  41.0
#         (42, 14, 'V1') :  None :                    0.0 :  41.0
#         (42, 14, 'V2') :  None :                    0.0 :  41.0
#         (42, 14, 'V3') :  None :                    0.0 :  41.0
#         (42, 14, 'V4') :  None :                   -2.0 :  41.0
#         (42, 14, 'V5') :  None :                    0.0 :  41.0
#         (42, 14, 'V6') :  None :                    0.0 :  41.0
#         (42, 15, 'V1') :  None :                    0.0 :  41.0
#         (42, 15, 'V2') :  None :                    0.0 :  41.0
#         (42, 15, 'V3') :  None :                    0.0 :  41.0
#         (42, 15, 'V4') :  None :                   41.0 :  41.0
#         (42, 15, 'V5') :  None :                    0.0 :  41.0
#         (42, 15, 'V6') :  None :                    0.0 :  41.0
#         (42, 16, 'V1') :  None :                    0.0 :  41.0
#         (42, 16, 'V2') :  None :                    0.0 :  41.0
#         (42, 16, 'V3') :  None :                    0.0 :  41.0
#         (42, 16, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 16, 'V5') :  None :                    0.0 :  41.0
#         (42, 16, 'V6') :  None :                    0.0 :  41.0
#         (42, 17, 'V1') :  None :                    0.0 :  41.0
#         (42, 17, 'V2') :  None :                    0.0 :  41.0
#         (42, 17, 'V3') :  None :                    0.0 :  41.0
#         (42, 17, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 17, 'V5') :  None :                    0.0 :  41.0
#         (42, 17, 'V6') :  None :                    0.0 :  41.0
#         (42, 18, 'V1') :  None :                    0.0 :  41.0
#         (42, 18, 'V2') :  None :                    0.0 :  41.0
#         (42, 18, 'V3') :  None :                    0.0 :  41.0
#         (42, 18, 'V4') :  None :     11.999999999999979 :  41.0
#         (42, 18, 'V5') :  None :                    0.0 :  41.0
#         (42, 18, 'V6') :  None :                    0.0 :  41.0
#         (42, 19, 'V1') :  None :                    0.0 :  41.0
#         (42, 19, 'V2') :  None :                    0.0 :  41.0
#         (42, 19, 'V3') :  None :                    0.0 :  41.0
#         (42, 19, 'V4') :  None :      7.999999999999979 :  41.0
#         (42, 19, 'V5') :  None :                    0.0 :  41.0
#         (42, 19, 'V6') :  None :                    0.0 :  41.0
#         (42, 20, 'V1') :  None :                    0.0 :  41.0
#         (42, 20, 'V2') :  None :                    0.0 :  41.0
#         (42, 20, 'V3') :  None :                    0.0 :  41.0
#         (42, 20, 'V4') :  None :                    3.0 :  41.0
#         (42, 20, 'V5') :  None :                    0.0 :  41.0
#         (42, 20, 'V6') :  None :                    0.0 :  41.0
#         (42, 21, 'V1') :  None :                    0.0 :  41.0
#         (42, 21, 'V2') :  None :                    0.0 :  41.0
#         (42, 21, 'V3') :  None :                    0.0 :  41.0
#         (42, 21, 'V4') :  None :                    2.0 :  41.0
#         (42, 21, 'V5') :  None :                    0.0 :  41.0
#         (42, 21, 'V6') :  None :                    0.0 :  41.0
#         (42, 22, 'V1') :  None :                    0.0 :  41.0
#         (42, 22, 'V2') :  None :                    0.0 :  41.0
#         (42, 22, 'V3') :  None :                    0.0 :  41.0
#         (42, 22, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 22, 'V5') :  None :                    0.0 :  41.0
#         (42, 22, 'V6') :  None :                    0.0 :  41.0
#         (42, 23, 'V1') :  None :                    0.0 :  41.0
#         (42, 23, 'V2') :  None :                    0.0 :  41.0
#         (42, 23, 'V3') :  None :                    0.0 :  41.0
#         (42, 23, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 23, 'V5') :  None :                    0.0 :  41.0
#         (42, 23, 'V6') :  None :                    0.0 :  41.0
#         (42, 24, 'V1') :  None :                    0.0 :  41.0
#         (42, 24, 'V2') :  None :                    0.0 :  41.0
#         (42, 24, 'V3') :  None :                    0.0 :  41.0
#         (42, 24, 'V4') :  None :     -5.999999999999989 :  41.0
#         (42, 24, 'V5') :  None :                    0.0 :  41.0
#         (42, 24, 'V6') :  None :                    0.0 :  41.0
#         (42, 25, 'V1') :  None :                    0.0 :  41.0
#         (42, 25, 'V2') :  None :                    0.0 :  41.0
#         (42, 25, 'V3') :  None :                    0.0 :  41.0
#         (42, 25, 'V4') :  None :     12.999999999999979 :  41.0
#         (42, 25, 'V5') :  None :                    0.0 :  41.0
#         (42, 25, 'V6') :  None :                    0.0 :  41.0
#         (42, 26, 'V1') :  None :                    0.0 :  41.0
#         (42, 26, 'V2') :  None :                    0.0 :  41.0
#         (42, 26, 'V3') :  None :                    0.0 :  41.0
#         (42, 26, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 26, 'V5') :  None :                    0.0 :  41.0
#         (42, 26, 'V6') :  None :                    0.0 :  41.0
#         (42, 27, 'V1') :  None :                    0.0 :  41.0
#         (42, 27, 'V2') :  None :                    0.0 :  41.0
#         (42, 27, 'V3') :  None :                    0.0 :  41.0
#         (42, 27, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 27, 'V5') :  None :                    0.0 :  41.0
#         (42, 27, 'V6') :  None :                    0.0 :  41.0
#         (42, 28, 'V1') :  None :                    0.0 :  41.0
#         (42, 28, 'V2') :  None :                    0.0 :  41.0
#         (42, 28, 'V3') :  None :                    0.0 :  41.0
#         (42, 28, 'V4') :  None :     -6.999999999999954 :  41.0
#         (42, 28, 'V5') :  None :                    0.0 :  41.0
#         (42, 28, 'V6') :  None :                    0.0 :  41.0
#         (42, 29, 'V1') :  None :                    0.0 :  41.0
#         (42, 29, 'V2') :  None :                    0.0 :  41.0
#         (42, 29, 'V3') :  None :                    0.0 :  41.0
#         (42, 29, 'V4') :  None :      5.999999999999979 :  41.0
#         (42, 29, 'V5') :  None :                    0.0 :  41.0
#         (42, 29, 'V6') :  None :                    0.0 :  41.0
#         (42, 30, 'V1') :  None :                    0.0 :  41.0
#         (42, 30, 'V2') :  None :                    0.0 :  41.0
#         (42, 30, 'V3') :  None :                    0.0 :  41.0
#         (42, 30, 'V4') :  None :                    4.0 :  41.0
#         (42, 30, 'V5') :  None :                    0.0 :  41.0
#         (42, 30, 'V6') :  None :                    0.0 :  41.0
#         (42, 31, 'V1') :  None :                    0.0 :  41.0
#         (42, 31, 'V2') :  None :                    0.0 :  41.0
#         (42, 31, 'V3') :  None :                    0.0 :  41.0
#         (42, 31, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 31, 'V5') :  None :                   -1.0 :  41.0
#         (42, 31, 'V6') :  None :                    0.0 :  41.0
#         (42, 32, 'V1') :  None :                    0.0 :  41.0
#         (42, 32, 'V2') :  None :                    0.0 :  41.0
#         (42, 32, 'V3') :  None :                    0.0 :  41.0
#         (42, 32, 'V4') :  None :                    1.0 :  41.0
#         (42, 32, 'V5') :  None :                    0.0 :  41.0
#         (42, 32, 'V6') :  None :                    0.0 :  41.0
#         (42, 33, 'V1') :  None :                    0.0 :  41.0
#         (42, 33, 'V2') :  None :                    0.0 :  41.0
#         (42, 33, 'V3') :  None :                    0.0 :  41.0
#         (42, 33, 'V4') :  None :      6.999999999999979 :  41.0
#         (42, 33, 'V5') :  None :                    0.0 :  41.0
#         (42, 33, 'V6') :  None :                    0.0 :  41.0
#         (42, 34, 'V1') :  None :                    0.0 :  41.0
#         (42, 34, 'V2') :  None :                    0.0 :  41.0
#         (42, 34, 'V3') :  None :                    0.0 :  41.0
#         (42, 34, 'V4') :  None :     -4.999999999999989 :  41.0
#         (42, 34, 'V5') :  None :                    0.0 :  41.0
#         (42, 34, 'V6') :  None :                    0.0 :  41.0
#         (42, 35, 'V1') :  None :                    0.0 :  41.0
#         (42, 35, 'V2') :  None :                    0.0 :  41.0
#         (42, 35, 'V3') :  None :                    0.0 :  41.0
#         (42, 35, 'V4') :  None :                   -4.0 :  41.0
#         (42, 35, 'V5') :  None :                    0.0 :  41.0
#         (42, 35, 'V6') :  None :                    0.0 :  41.0
#         (42, 36, 'V1') :  None :                    0.0 :  41.0
#         (42, 36, 'V2') :  None :                    0.0 :  41.0
#         (42, 36, 'V3') :  None :                    0.0 :  41.0
#         (42, 36, 'V4') :  None :     10.999999999999979 :  41.0
#         (42, 36, 'V5') :  None :                    0.0 :  41.0
#         (42, 36, 'V6') :  None :                    0.0 :  41.0
#         (42, 37, 'V1') :  None :                    0.0 :  41.0
#         (42, 37, 'V2') :  None :                    0.0 :  41.0
#         (42, 37, 'V3') :  None :                    0.0 :  41.0
#         (42, 37, 'V4') :  None :      8.999999999999984 :  41.0
#         (42, 37, 'V5') :  None :                    0.0 :  41.0
#         (42, 37, 'V6') :  None :                    0.0 :  41.0
#         (42, 38, 'V1') :  None :                    0.0 :  41.0
#         (42, 38, 'V2') :  None :                    0.0 :  41.0
#         (42, 38, 'V3') :  None :                    0.0 :  41.0
#         (42, 38, 'V4') :  None :                    5.0 :  41.0
#         (42, 38, 'V5') :  None :                    0.0 :  41.0
#         (42, 38, 'V6') :  None :                    0.0 :  41.0
#         (42, 39, 'V1') :  None :                    0.0 :  41.0
#         (42, 39, 'V2') :  None :                    0.0 :  41.0
#         (42, 39, 'V3') :  None :                    0.0 :  41.0
#         (42, 39, 'V4') :  None :     13.999999999999972 :  41.0
#         (42, 39, 'V5') :  None :                   -2.0 :  41.0
#         (42, 39, 'V6') :  None :                    0.0 :  41.0
#         (42, 40, 'V1') :  None :                    0.0 :  41.0
#         (42, 40, 'V2') :  None :                    0.0 :  41.0
#         (42, 40, 'V3') :  None :                    0.0 :  41.0
#         (42, 40, 'V4') :  None :      9.999999999999979 :  41.0
#         (42, 40, 'V5') :  None :                    0.0 :  41.0
#         (42, 40, 'V6') :  None :                    0.0 :  41.0
#         (42, 41, 'V1') :  None :                    0.0 :  41.0
#         (42, 41, 'V2') :  None :                    0.0 :  41.0
#         (42, 41, 'V3') :  None :                    0.0 :  41.0
#         (42, 41, 'V4') :  None :     -7.999999999999911 :  41.0
#         (42, 41, 'V5') :  None :                    0.0 :  41.0
#         (42, 41, 'V6') :  None :                    0.0 :  41.0
#     restriccion_sale_vehiculo : Size=6
#         Key : Lower : Body               : Upper
#          V1 :   1.0 :                1.0 :   1.0
#          V2 :   1.0 :                1.0 :   1.0
#          V3 :   1.0 :                1.0 :   1.0
#          V4 :   1.0 : 0.9999999999999997 :   1.0
#          V5 :   1.0 :                1.0 :   1.0
#          V6 :   1.0 :                1.0 :   1.0
#     restriccion_entra_vehiculo : Size=6
#         Key : Lower : Body : Upper
#          V1 :   1.0 :  1.0 :   1.0
#          V2 :   1.0 :  1.0 :   1.0
#          V3 :   1.0 :  1.0 :   1.0
#          V4 :   1.0 :  1.0 :   1.0
#          V5 :   1.0 :  1.0 :   1.0
#          V6 :   1.0 :  1.0 :   1.0

# %%
vrp.exportar_rutas_a_csv("rutas_Case2.csv")
print("Costo total: ", vrp.model.obj())
# Out:
# Rutas exportadas a rutas_Case2.csv
# Costo total:  697622.5499999999
