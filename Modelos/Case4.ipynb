# %%
from pyomo.environ import * 
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import folium 
from folium.plugins import AntPath


# Cambiar las rutas de los archivos
clients = pd.read_csv(r'case_4_multi_product\Clients.csv')  # Clientes
depots = pd.read_csv(r'case_4_multi_product\Depots.csv')    # Depósitos
distancias = pd.read_csv(r'Matrices/distancias4.csv')  # Matriz de distancias
tiempos = pd.read_csv(r'Matrices/tiempos4.csv')        # Matriz de tiempos
vehicles = pd.read_csv(r'case_4_multi_product\Vehicles.csv')    # Vehículos
costos_operativos = pd.read_csv(r'case_4_costs_vehicles\costos_operativos_combinados4.csv')   # Costos Operativos 
capacidades_centro = pd.read_csv(r'case_4_multi_product\DepotCapacities.csv')  # Capacidad de los centros



# Daily Maintenance [COP/day]
costos_mantenimiento = {
    'V1': 30000,
    'V2': 21000,
    'V3': 21000,
    'V4': 3000,
    'V5': 3000,
    'V6': 3000,
}

costos_mantenimiento_total = sum(costos_mantenimiento.values())

vehicles['ID'] = ['V' + str(i+1) for i in range(len(vehicles))]

# Crear conjuntos
distancias_dict = {(int(row["Desde"]+1), int(row["Hacia"]+1)): row["Distancia"] for _, row in distancias.iterrows()}


clientes = clients['LocationID'].tolist()  # IDs de los clientes
centros = depots['LocationID'].tolist()   # IDs de los depósitos
vehiculos = vehicles['ID'].tolist()  # IDs de los vehículos
nodos = centros + clientes  # Todos los nodos (clientes + depósitos)
clients.columns = clients.columns.str.strip()
depots.columns = depots.columns.str.strip()

# Crear parámetros
productos = ['Product-Type-A', 'Product-Type-B', 'Product-Type-C']  # Definimos los tipos de productos

demandas_clients = {
    (int(row['LocationID']), p): row[p]
    for _, row in clients.iterrows()
    for p in productos
}

demanda_centros = {
    (row['LocationID'], p): 0
    for _, row in depots.iterrows()
    for p in productos
}




# 2. Capacidades de los vehículos (Vehicles.csv)
capacidad_vehiculo = {row['ID']: row['Capacity'] for _, row in vehicles.iterrows()}

# 3. Rango máximo de los vehículos (Vehicles.csv)
rango_vehiculo = {row['ID']: row['Range']*1000 for _, row in vehicles.iterrows()}
print(rango_vehiculo)
# 4. Costo operativo 
costos_operativos_dict = {(row['Vehiculo'], row['Desde'], row['Hacia']): row['Costo'] 
                          for _, row in costos_operativos.iterrows()}



# 6. Capacidades de los centros de distribución (Depots.csv)
capacidades_centros = {
    (row['DepotID'], p): row[p] 
    for _, row in capacidades_centro.iterrows()
    for p in ['Product-Type-A', 'Product-Type-B', 'Product-Type-C']
}


# 7. Distancias y tiempos (distancias1.csv y tiempos1.csv)

tiempos_dict = {(row['Desde'], row['Hacia']): row['Tiempo'] for _, row in tiempos.iterrows()}
# Crear diccionario de coordenadas para todos los nodos
all_coords = {
    **{row['LocationID']: (row['Latitude'], row['Longitude']) for _, row in clients.iterrows()},
    **{row['LocationID']: (row['Latitude'], row['Longitude']) for _, row in depots.iterrows()}
}


# Validar dimensiones
print(f"Clientes: {len(clientes)}, Centros: {len(centros)}, Vehículos: {len(vehiculos)}, Nodos: {len(nodos)}")
# Out:
# {'V1': 145852.07096486446, 'V2': 1304605.971281605, 'V3': 953172.608610164, 'V4': 17302.30418745873, 'V5': 16627.680130757893, 'V6': 13602.810739289229}
# Clientes: 9, Centros: 12, Vehículos: 6, Nodos: 21

# %%
class VRPModel:
    def __init__(self, clientes, centros, vehiculos, productos, distancias_dict, tiempos, demandas_clients, capacidad_vehiculo, rango_vehiculo, costos_operativos_dict, costos_mantenimiento,all_coords,capacidades_centros):
        """
        Inicializar parámetros del modelo VRP.
        """
        # Conjuntos y parámetros
        self.clientes = clientes
        self.centros = centros
        self.vehiculos = vehiculos
        self.productos = productos
        self.nodos = clientes + centros
        self.distancias_dict = distancias_dict
        self.tiempos = tiempos
        self.demandas_clients = demandas_clients
        self.capacidad_vehiculo = capacidad_vehiculo
        self.rango_vehiculo = rango_vehiculo
        self.costos_operativos_dict= costos_operativos_dict
        self.costos_mantenimiento = costos_mantenimiento
        self.all_coords = all_coords
        self.capacidades_centros = capacidades_centros

        
        
        # Crear modelo Pyomo
        self.model = ConcreteModel()

    def build_model(self):
        """
        Construir el modelo de optimización.
        """
        model = self.model

        # Sets
        model.C = Set(initialize=self.clientes)
        model.D = Set(initialize=self.centros)
        model.V = Set(initialize=self.vehiculos)
        model.P = Set(initialize=self.productos)
        model.N = Set(initialize=self.nodos) 

        # Variables
        model.x = Var(model.N, model.N, model.V, within=Binary)  # Ruta del vehículo
        model.z = Var(model.V, within=Binary)  # Activación del vehículo
        model.q = Var(model.N, model.P, model.V, within=NonNegativeReals)  # Carga transportada

        # Función objetivo: Minimizar costos
        def obj_expression(model):
            return sum(
                # Costos por distancia
                model.x[i, j, v] * costos_operativos_dict[(v, i, j)]
                for v in model.V for i in model.N for j in model.N if (v, i, j) in costos_operativos_dict) + costos_mantenimiento_total
            
        model.obj = Objective(rule=obj_expression, sense=minimize)
        
        # Restricciones

        # 1. Cada cliente debe ser visitado exactamente una vez
        def restriccion_visita_unica(model, i):
            return sum(model.x[i, j, v] for j in model.N for v in model.V if i != j) == 1
        model.restriccion_visita_unica = Constraint(model.C, rule=restriccion_visita_unica)

        # 2. Conservación del flujo en los nodos
        def restriccion_flujo(model, i, v):
            return sum(model.x[i, j, v] for j in model.N if i != j) == sum(model.x[j, i, v] for j in model.N if i != j)
        model.restriccion_flujo = Constraint(model.N, model.V, rule=restriccion_flujo)

        # 3. Capacidad de los vehículos
        def restriccion_capacidad_vehiculo_total(model, v):
            return sum(model.q[i, p, v] for i in model.C for p in model.P) <= self.capacidad_vehiculo[v]
        model.restriccion_capacidad_vehiculo_total = Constraint(model.V, rule=restriccion_capacidad_vehiculo_total)


        #4. No viajes a si mismo
        def restriccion_no_viajes(model, i, v):
            return model.x[i, i, v] == 0
        model.restriccion_no_viajes = Constraint(model.N, model.V, rule=restriccion_no_viajes)
        
        #5. No viaaje de un deposito a otro deposito
        def restriccion_no_viajes_centros(model, i, j, v):
            return model.x[i, j, v] == 0
        model.restriccion_no_viajes_centros = Constraint(model.D, model.D, model.V, rule=restriccion_no_viajes_centros)
        
        # 5. Capacidad de los centros de distribución
        # Restricción de capacidad por producto en los centros
        def restriccion_capacidad_centro_producto(model, k, p):
            return sum(
                model.q[i, p, v] for i in model.C for v in model.V
            ) <= self.capacidades_centros[(k, p)]
        model.restriccion_capacidad_centro_producto = Constraint(
            model.D, model.P, rule=restriccion_capacidad_centro_producto
        )
        



        # 6. Límite de rango de los vehículos
        def restriccion_rango_vehiculo(model, v):
            return sum(self.distancias_dict[(i, j)] * model.x[i, j, v] for i in model.N for j in model.N if i != j) <= self.rango_vehiculo[v]
        model.restriccion_rango_vehiculo = Constraint(model.V, rule=restriccion_rango_vehiculo)
        
        #7. Restricción de activación de vehículos
        M= len(self.nodos)
        def restriccion_activacion_vehiculo(model, v):
            return sum(model.x[i, j, v] for i in model.N for j in model.N if i != j) <= M * model.z[v]
        model.restriccion_activacion_vehiculo = Constraint(model.V, rule=restriccion_activacion_vehiculo)

        # 8. Eliminación de subtours (MTZ)
        model.u = Var(model.N, model.V, within=NonNegativeReals)
        def restriccion_subtours(model, i, j, v):
            if i != j:
                return model.u[i, v] - model.u[j, v] + len(model.N) * model.x[i, j, v] <= len(model.N) - 1
            return Constraint.Skip
        model.restriccion_subtours = Constraint(model.C, model.C, model.V, rule=restriccion_subtours)

        #9. Sale de un centro depot
        def restriccion_sale_vehiculo(model,v):
            return sum(model.x[d,j,v] for d in model.D for j in model.N)==1
        model.restriccion_sale_vehiculo= Constraint(model.V, rule= restriccion_sale_vehiculo)
        
        def restriccion_entra_vehiculo(model,v):
            return sum(model.x[i,d,v] for d in model.D for i in model.N)==1
        model.restriccion_entra_vehiculo= Constraint(model.V, rule= restriccion_entra_vehiculo)
        
        return model
    

    
    
    def solve_model(self):
        """
        Resolver el modelo utilizando HiGHS.
        """
        solver_name = "appsi_highs"
        solver = SolverFactory(solver_name)
        solver.options['parallel'] = 'on'
        solver.options['time_limit'] = 5*60  # 1-hour time limit
        solver.options['presolve'] = 'on'
        solver.options['mip_rel_gap'] = 0.01  # 1% relative gap
        solver.options['simplex_strategy'] = 1  # Dual simplex
        solver.options['simplex_max_concurrency'] = 8  # Max concurrency
        solver.options['mip_min_logging_interval'] = 10  # Log every 10 seconds
        solver.options['mip_heuristic_effort'] = 0.2  # Increase heuristic effort

        # Resolver el modelo
        result = solver.solve(self.model, tee=True)

        # Verificar el estado del solver
        if result.solver.termination_condition == TerminationCondition.infeasible:
            print("El modelo es infactible.")
        elif result.solver.termination_condition == TerminationCondition.optimal:
            print("Se encontró una solución óptima.")
            # Cargar la solución si es óptima
            self.model.solutions.load_from(result)
        elif result.solver.termination_condition == TerminationCondition.unbounded:
            print("El modelo es no acotado.")
        elif result.solver.termination_condition == TerminationCondition.maxTimeLimit:
            print("Se alcanzó el límite de tiempo.")
        else:
            print(f"Condición de terminación desconocida: {result.solver.termination_condition}")

        print(result)

        
    def display_results(self):
        print("\nRutas asignadas por vehículo:")
        for v in self.vehiculos:
            print(f"Vehículo: {v}")
            for i in self.nodos:
                for j in self.nodos:
                    if i != j and round(value(self.model.x[i, j, v])) == 1:  # Redondeamos el valor
                        print(f"   De {i} a {j}")
                        

    def visualize_routes_with_map(self):
        selected_routes = []
        for v in self.vehiculos:
            routes_for_v = [
                (i, j) for i in self.nodos for j in self.nodos
                if i != j and round(value(self.model.x[i, j, v])) == 1
            ]
            print(f"Rutas seleccionadas para el vehículo {v}: {routes_for_v}")
            selected_routes.append(routes_for_v)

        # Preparar colores y nodos
        colors = ['green', 'orange', 'darkblue', 'darkred', 'red', 'purple', 'black']
        node_colors = {}
        for k in range(len(self.vehiculos)):
            for route in selected_routes[k]:
                i, j = route
                idx_color = k % len(colors)
                if i not in node_colors and i > len(self.centros):
                    node_colors[i] = colors[idx_color]
                if j not in node_colors and j > len(self.centros):
                    node_colors[j] = colors[idx_color]

        # Crear el mapa
        mapa = folium.Map(location=all_coords[self.centros[0]], zoom_start=12)
        for idx in all_coords:
            lat, lon = all_coords[idx]
            icon, color = ("warehouse", 'gray') if idx in self.centros else ("envelope", node_colors.get(idx, "black"))

            folium.Marker(
                location=(lat, lon),
                popup=f"Nodo {idx}",
                icon=folium.Icon(color=color, icon=icon, prefix="fa"),
            ).add_to(mapa)

        for k in range(len(self.vehiculos)):
            for route in selected_routes[k]:
                i, j = route
                idx_color = k % len(colors)

                AntPath(
                    locations=[all_coords[i], all_coords[j]],
                    tooltip=f"Vehículo {self.vehiculos[k]}: {i} -> {j}",
                    color=colors[idx_color],
                ).add_to(mapa)

        # Guardar el mapa
        mapa.save("mapa_rutas_optimizadas.html")
        print("Mapa guardado como mapa_rutas_optimizadas.html")
        return mapa
    
    def exportar_rutas_a_csv(self, archivo_csv="rutas_asignadas.csv"):
        """
        Exporta las rutas asignadas por vehículo a un archivo CSV.
        
        Parámetros:
            archivo_csv (str): Nombre del archivo CSV de salida.
        """
        rutas = []

        # Recolectar las rutas asignadas
        for v in self.vehiculos:
            for i in self.nodos:
                for j in self.nodos:
                    if i != j and round(value(self.model.x[i, j, v])) == 1:  # Ruta activa
                        rutas.append({
                            "Vehículo": v,
                            "Origen": i,
                            "Destino": j
                        })

        # Crear un DataFrame de pandas con las rutas
        df_rutas = pd.DataFrame(rutas)

        # Exportar a CSV
        df_rutas.to_csv(archivo_csv, index=False)
        print(f"Rutas exportadas a {archivo_csv}")

# %%
# Instanciar la clase del modelo
vrp = VRPModel(
    clientes=clientes,
    centros=centros,
    vehiculos=vehiculos,
    productos=productos,
    distancias_dict=distancias_dict,
    tiempos=tiempos,
    demandas_clients=demandas_clients,
    capacidad_vehiculo=capacidad_vehiculo,
    rango_vehiculo=rango_vehiculo,
    costos_operativos_dict=costos_operativos_dict,
    costos_mantenimiento=costos_mantenimiento,
    all_coords=all_coords,
    capacidades_centros=capacidades_centros
)

# Construir el modelo
vrp.build_model()

# Resolver el modelo
vrp.solve_model()

vrp.display_results()
# Out:
# Running HiGHS 1.8.1 (git hash: 4a7f24a): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 4e+04]
#   Cost   [2e+03, 2e+05]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+06]
# Presolving model
# 590 rows, 1439 cols, 8664 nonzeros  0s
# 561 rows, 1125 cols, 6121 nonzeros  0s
# 514 rows, 1120 cols, 6036 nonzeros  0s
#
# Solving MIP model with:
#    514 rows
#    1120 cols (1066 binary, 0 integer, 0 implied int., 54 continuous)
#    6036 nonzeros
# MIP-Timing:         0.6 - starting analytic centre calculation
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   81000           inf                  inf        0      0      0         0     0.6s
#  R       0       0         0   0.00%   216475.616667   438641.85         50.65%        0      0      0       173     0.6s
#  L       0       0         0   0.00%   225730.678389   259806.033333     13.12%      733     46      9       570     3.0s
#
# 48.1% inactive integer columns, restarting
# Model after restart has 441 rows, 566 cols (512 bin., 0 int., 0 impl., 54 cont.), and 3230 nonzeros
#
#          0       0         0   0.00%   225771.703377   259806.033333     13.10%       21      0      0      1778     3.8s
#          0       0         0   0.00%   225771.703377   259806.033333     13.10%       21     19      4      1857     3.8s
#  L       0       0         0   0.00%   226468.77008    259806.033333     12.83%     1072     32      4      2311     5.9s
#  B      14       2         5  68.75%   228191.905675   259806.033333     12.17%     1047     24    588      8509     8.2s
#  B      14       2         5  68.75%   228191.905675   259806.033333     12.17%     1051     24    601      8509     8.2s
#  B      24       2         9  74.22%   245100.008333   258964.816667      5.35%     1143     32   1088     10165     8.7s
#  B      27       2        10  74.41%   245100.008333   258964.816667      5.35%     1151     32   1209     10423     8.8s
#         33       0        13 100.00%   256504.65       258964.816667      0.95%     1299     21   1653     11409     9.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      258964.816667
#   Dual bound        256504.65
#   Gap               0.95% (tolerance: 1%)
#   P-D integral      1.87505732995
#   Solution status   feasible
#                     258964.816667 (objective)
#                     0 (bound viol.)
#                     7.3539016091e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            9.05 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 4
#   Nodes             33
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     11409 (total)
#                     6539 (strong br.)
#                     1009 (separation)
#                     2553 (heuristics)
# Se encontró una solución óptima.
#
# Problem:
# - Lower bound: 256504.65
#   Upper bound: 258964.8166666666
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 0
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Termination message: TerminationCondition.optimal
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#
# Rutas asignadas por vehículo:
# Vehículo: V1
#    De 17 a 6
#    De 6 a 17
# Vehículo: V2
#    De 13 a 20
#    De 20 a 21
#    De 21 a 5
#    De 5 a 13
# Vehículo: V3
#    De 14 a 5
#    De 5 a 14
# Vehículo: V4
#    De 18 a 10
#    De 10 a 18
# Vehículo: V5
#    De 15 a 6
#    De 16 a 15
#    De 6 a 16
# Vehículo: V6
#    De 19 a 9
#    De 9 a 19

# %%
vrp.visualize_routes_with_map()
# Out:
# Rutas seleccionadas para el vehículo V1: [(17, 6), (6, 17)]
# Rutas seleccionadas para el vehículo V2: [(13, 20), (20, 21), (21, 5), (5, 13)]
# Rutas seleccionadas para el vehículo V3: [(14, 5), (5, 14)]
# Rutas seleccionadas para el vehículo V4: [(18, 10), (10, 18)]
# Rutas seleccionadas para el vehículo V5: [(15, 6), (16, 15), (6, 16)]
# Rutas seleccionadas para el vehículo V6: [(19, 9), (9, 19)]
# Mapa guardado como mapa_rutas_optimizadas.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f331eeb350534e367d5919384d99b886 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f331eeb350534e367d5919384d99b886&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f331eeb350534e367d5919384d99b886 = L.map(
#                 &quot;map_f331eeb350534e367d5919384d99b886&quot;,
#                 {
#                     center: [4.75021190869025, -74.08124218159384],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4bfe744c8693ceff586922a90a38c71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e4bfe744c8693ceff586922a90a38c71.addTo(map_f331eeb350534e367d5919384d99b886);
#
#
#             var marker_dc59d51c2b66ded2f605c114a2379627 = L.marker(
#                 [4.632552840424734, -74.19699184741948],
#                 {}
#             ).addTo(map_f331eeb350534e367d5919384d99b886);
#
#
#             var icon_a62aa33c06ae917fcf35384988435913 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;envelope&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dc59d51c2b66ded2f605c114a2379627.setIcon(icon_a62aa33c06ae917fcf35384988435913);
#
#
#         var popup_1ceb319209df38a22421c297a891569d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16c2b37c399061c2e30de5848de2c3ab = $(`&lt;div id=&quot;html_16c2b37c399061c2e30de5848de2c3ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nodo 13.0&lt;/div&gt;`)[0];
#                 popup_1ceb319209df38a22421c297a891569d.setContent(html_16c2b37c399061c2e30de5848de2c3ab);
#
#
#
#         marker_dc59d51c2b66ded2f605c114a2379627.bindPopup(popup_1ceb319209df38a22421c297a891569d)
#         ;
#
#
#
#
#             var marker_1c3c9e2ed8cdeab53aa1943a00f8cef9 = L.marker(
#                 [4.719616298449461, -74.12032773611021],
#                 {}
#             ).addTo(map_f331eeb350534e367d5919384d99b886);
#
#
#             var icon_ba258b9d8e3eb07c097851379ff3cf23 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;envelope&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1c3c9e2ed8cdeab53aa1943a00f8cef9.setIcon(icon_ba258b9d8e3eb07c097851379ff3cf23);
#
#
#         var popup_487733e23823cb989332e89f0d2200e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_129d13259b6d351c1ec79b35ff18e60d = $(`&lt;div id=&quot;html_129d13259b6d351c1ec79b35ff18e60d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nodo 14.0&lt;/div&gt;`)[0];
#                 popup_487733e23823cb989332e89f0d2200e8.setContent(html_129d13259b6d351c1ec79b35ff18e60d);
#
#
#
#         marker_1c3c9e2ed8cdeab53aa1943a00f8cef9.bindPopup(popup_487733e23823cb989332e89f0d2200e8)
#         ;
#
#
#
#
#             var marker_126865d11d1623bb8a50028c4bd74951 = L.marker(
#                 [4.727691608175209, -74.11027242131048],
#                 {}
#             ).addTo(map_f331eeb350534e367d5919384d99b886);
#
#
#             var icon_5568c76e89a88d5ee2c23d16551bdafa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;envelope&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_126865d11d1623bb8a50028c4bd74951.setIcon(icon_5568c76e89a88d5ee2c23d16551bdafa);
#
#
#         var popup_666349d348763bd3c6338edec97625d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cce1c67eb2c513f5643e1d888d742488 = $(`&lt;div id=&quot;html_cce1c67eb2c513f5643e1d888d742488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nodo 15.0&lt;/div&gt;`)[0];
#                 popup_666349d348763bd3c6338edec97625d3.setContent(html_cce1c67eb2c513f5643e1d888d742488);
#
#
#
#         marker_126865d11d1623bb8a50028c4bd74951.bindPopup(popup_666349d348763bd3c6338edec97625d3)
#         ;
#
#
#
#
#             var marker_d3a0b3aaf41ee5492641c9d78adac14d = L.marker(
#                 [4.712202539809157, -74.06815337963502],
#                 {}
#             ).addTo(map_f331eeb350534e367d5919384d99b886);
#
#
#             var icon_2a68929aed7944ba8823050392cc6

# %%
vrp.model.display()
# Out:
# Model unknown
#
#   Variables:
#     x : Size=2646, Index=N*N*V
#         Key            : Lower : Value                   : Upper : Fixed : Stale : Domain
#           (1, 1, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 1, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 1, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 1, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 1, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 1, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 2, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 2, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 2, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 2, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 2, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 2, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 3, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 3, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 3, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 3, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 3, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 3, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 4, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 4, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 4, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 4, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 4, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 4, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 5, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 5, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 5, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 5, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 5, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 5, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 6, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 6, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 6, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 6, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 6, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 6, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 7, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 7, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 7, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 7, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 7, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 7, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 8, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 8, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 8, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 8, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 8, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 8, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 9, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 9, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 9, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 9, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 9, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (1, 9, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 10, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 10, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 10, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 10, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 10, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 10, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 11, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 11, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 11, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 11, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 11, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 11, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 12, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 12, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 12, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 12, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 12, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 12, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 13, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 13, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 13, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 13, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 13, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 13, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 14, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 14, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 14, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 14, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 14, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 14, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 15, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 15, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 15, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 15, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 15, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 15, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 16, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 16, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 16, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 16, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 16, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 16, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 17, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 17, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 17, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 17, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 17, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 17, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 18, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 18, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 18, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 18, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 18, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 18, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 19, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 19, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 19, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 19, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 19, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 19, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 20, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 20, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 20, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 20, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 20, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 20, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 21, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 21, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 21, 'V3') :     0 :                    -0.0 :     1 : False : False : Binary
#          (1, 21, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 21, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (1, 21, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 1, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 1, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 1, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 1, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 1, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 1, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 2, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 2, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 2, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 2, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 2, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 2, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 3, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 3, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 3, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 3, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 3, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 3, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 4, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 4, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 4, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 4, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 4, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 4, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 5, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 5, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 5, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 5, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 5, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 5, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 6, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 6, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 6, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 6, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 6, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 6, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 7, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 7, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 7, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 7, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 7, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 7, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 8, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 8, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 8, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 8, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 8, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 8, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 9, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 9, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 9, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 9, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 9, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (2, 9, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 10, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 10, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 10, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 10, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 10, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 10, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 11, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 11, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 11, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 11, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 11, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 11, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 12, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 12, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 12, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 12, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 12, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 12, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 13, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 13, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 13, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 13, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 13, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 13, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 14, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 14, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 14, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 14, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 14, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 14, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 15, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 15, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 15, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 15, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 15, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 15, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 16, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 16, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 16, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 16, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 16, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 16, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 17, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 17, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 17, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 17, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 17, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 17, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 18, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 18, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 18, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 18, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 18, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 18, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 19, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 19, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 19, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 19, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 19, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 19, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 20, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 20, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 20, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 20, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 20, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 20, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 21, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 21, 'V2') :     0 :                    -0.0 :     1 : False : False : Binary
#          (2, 21, 'V3') :     0 :                    -0.0 :     1 : False : False : Binary
#          (2, 21, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 21, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (2, 21, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 1, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 1, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 1, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 1, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 1, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 1, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 2, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 2, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 2, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 2, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 2, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 2, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 3, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 3, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 3, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 3, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 3, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 3, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 4, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 4, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 4, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 4, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 4, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 4, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 5, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 5, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 5, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 5, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 5, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 5, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 6, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 6, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 6, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 6, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 6, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 6, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 7, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 7, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 7, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 7, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 7, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 7, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 8, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 8, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 8, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 8, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 8, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 8, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 9, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 9, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 9, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 9, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 9, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (3, 9, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 10, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 10, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 10, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 10, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 10, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 10, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 11, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 11, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 11, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 11, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 11, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 11, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 12, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 12, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 12, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 12, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 12, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 12, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 13, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 13, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 13, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 13, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 13, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 13, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 14, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 14, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 14, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 14, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 14, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 14, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 15, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 15, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 15, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 15, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 15, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 15, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 16, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 16, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 16, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 16, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 16, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 16, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 17, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 17, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 17, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 17, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 17, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 17, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 18, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 18, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 18, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 18, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 18, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 18, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 19, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 19, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 19, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 19, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 19, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 19, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 20, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 20, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 20, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 20, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 20, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 20, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 21, 'V1') :     0 :                    -0.0 :     1 : False : False : Binary
#          (3, 21, 'V2') :     0 :                    -0.0 :     1 : False : False : Binary
#          (3, 21, 'V3') :     0 :                    -0.0 :     1 : False : False : Binary
#          (3, 21, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 21, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (3, 21, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 1, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 1, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 1, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 1, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 1, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 1, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 2, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 2, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 2, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 2, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 2, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 2, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 3, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 3, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 3, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 3, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 3, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 3, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 4, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 4, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 4, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 4, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 4, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 4, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 5, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 5, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 5, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 5, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 5, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 5, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 6, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 6, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 6, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 6, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 6, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 6, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 7, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 7, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 7, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 7, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 7, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 7, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 8, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 8, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 8, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 8, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 8, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 8, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 9, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 9, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 9, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 9, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 9, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (4, 9, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 10, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 10, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 10, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 10, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 10, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 10, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 11, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 11, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 11, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 11, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 11, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 11, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 12, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 12, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 12, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 12, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 12, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 12, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 13, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 13, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 13, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 13, 'V4') :     0 :  -7.353901609099748e-15 :     1 : False : False : Binary
#          (4, 13, 'V5') :     0 :  3.0170929191577416e-15 :     1 : False : False : Binary
#          (4, 13, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 14, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 14, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 14, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 14, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 14, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 14, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 15, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 15, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 15, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 15, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 15, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 15, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 16, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 16, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 16, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 16, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 16, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 16, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 17, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 17, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 17, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 17, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 17, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 17, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 18, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 18, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 18, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 18, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 18, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 18, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 19, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 19, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 19, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 19, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 19, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 19, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 20, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 20, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 20, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 20, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 20, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 20, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 21, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 21, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 21, 'V3') :     0 :                    -0.0 :     1 : False : False : Binary
#          (4, 21, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 21, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#          (4, 21, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 1, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 1, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 1, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 1, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 1, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 1, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 2, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 2, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 2, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 2, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 2, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 2, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 3, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 3, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 3, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 3, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 3, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 3, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 4, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 4, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 4, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 4, 'V4') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 4, 'V5') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 4, 'V6') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 5, 'V1') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 5, 'V2') :     0 :                     0.0 :     1 : False : False : Binary
#           (5, 5, 'V3') :     0 :                     0.0 :     1 : False : False : Binary
# ...
#         (17, 14, 'V1') :  None :                     0.0 :  20.0
#         (17, 14, 'V2') :  None :                     0.0 :  20.0
#         (17, 14, 'V3') :  None :                     0.0 :  20.0
#         (17, 14, 'V4') :  None :                     0.0 :  20.0
#         (17, 14, 'V5') :  None :                     0.0 :  20.0
#         (17, 14, 'V6') :  None :                     0.0 :  20.0
#         (17, 15, 'V1') :  None :                     0.0 :  20.0
#         (17, 15, 'V2') :  None :                     0.0 :  20.0
#         (17, 15, 'V3') :  None :                     0.0 :  20.0
#         (17, 15, 'V4') :  None :                     0.0 :  20.0
#         (17, 15, 'V5') :  None :                    -1.0 :  20.0
#         (17, 15, 'V6') :  None :                     0.0 :  20.0
#         (17, 16, 'V1') :  None :                     0.0 :  20.0
#         (17, 16, 'V2') :  None :                     0.0 :  20.0
#         (17, 16, 'V3') :  None :                     0.0 :  20.0
#         (17, 16, 'V4') :  None :                     0.0 :  20.0
#         (17, 16, 'V5') :  None :                     0.0 :  20.0
#         (17, 16, 'V6') :  None :                     0.0 :  20.0
#         (17, 18, 'V1') :  None :                     0.0 :  20.0
#         (17, 18, 'V2') :  None :                     0.0 :  20.0
#         (17, 18, 'V3') :  None :                     0.0 :  20.0
#         (17, 18, 'V4') :  None :                     0.0 :  20.0
#         (17, 18, 'V5') :  None :                     0.0 :  20.0
#         (17, 18, 'V6') :  None :                     0.0 :  20.0
#         (17, 19, 'V1') :  None :                     0.0 :  20.0
#         (17, 19, 'V2') :  None :                     0.0 :  20.0
#         (17, 19, 'V3') :  None :                     0.0 :  20.0
#         (17, 19, 'V4') :  None :                     0.0 :  20.0
#         (17, 19, 'V5') :  None :                     0.0 :  20.0
#         (17, 19, 'V6') :  None :                     0.0 :  20.0
#         (17, 20, 'V1') :  None :                     0.0 :  20.0
#         (17, 20, 'V2') :  None :     -0.9999999999999751 :  20.0
#         (17, 20, 'V3') :  None :                     0.0 :  20.0
#         (17, 20, 'V4') :  None :                     0.0 :  20.0
#         (17, 20, 'V5') :  None :                     0.0 :  20.0
#         (17, 20, 'V6') :  None :                     0.0 :  20.0
#         (17, 21, 'V1') :  None :                     0.0 :  20.0
#         (17, 21, 'V2') :  None :       -1.99999999999992 :  20.0
#         (17, 21, 'V3') :  None :                     0.0 :  20.0
#         (17, 21, 'V4') :  None :                     0.0 :  20.0
#         (17, 21, 'V5') :  None :                     0.0 :  20.0
#         (17, 21, 'V6') :  None :                     0.0 :  20.0
#         (18, 13, 'V1') :  None :                     0.0 :  20.0
#         (18, 13, 'V2') :  None :                     0.0 :  20.0
#         (18, 13, 'V3') :  None :                     0.0 :  20.0
#         (18, 13, 'V4') :  None :                     0.0 :  20.0
#         (18, 13, 'V5') :  None :                     0.0 :  20.0
#         (18, 13, 'V6') :  None :                     0.0 :  20.0
#         (18, 14, 'V1') :  None :                     0.0 :  20.0
#         (18, 14, 'V2') :  None :                     0.0 :  20.0
#         (18, 14, 'V3') :  None :                     0.0 :  20.0
#         (18, 14, 'V4') :  None :                     0.0 :  20.0
#         (18, 14, 'V5') :  None :                     0.0 :  20.0
#         (18, 14, 'V6') :  None :                     0.0 :  20.0
#         (18, 15, 'V1') :  None :                     0.0 :  20.0
#         (18, 15, 'V2') :  None :                     0.0 :  20.0
#         (18, 15, 'V3') :  None :                     0.0 :  20.0
#         (18, 15, 'V4') :  None :                     0.0 :  20.0
#         (18, 15, 'V5') :  None :                    -1.0 :  20.0
#         (18, 15, 'V6') :  None :                     0.0 :  20.0
#         (18, 16, 'V1') :  None :                     0.0 :  20.0
#         (18, 16, 'V2') :  None :                     0.0 :  20.0
#         (18, 16, 'V3') :  None :                     0.0 :  20.0
#         (18, 16, 'V4') :  None :                     0.0 :  20.0
#         (18, 16, 'V5') :  None :                     0.0 :  20.0
#         (18, 16, 'V6') :  None :                     0.0 :  20.0
#         (18, 17, 'V1') :  None :                     0.0 :  20.0
#         (18, 17, 'V2') :  None :                     0.0 :  20.0
#         (18, 17, 'V3') :  None :                     0.0 :  20.0
#         (18, 17, 'V4') :  None :                     0.0 :  20.0
#         (18, 17, 'V5') :  None :                     0.0 :  20.0
#         (18, 17, 'V6') :  None :                     0.0 :  20.0
#         (18, 19, 'V1') :  None :                     0.0 :  20.0
#         (18, 19, 'V2') :  None :                     0.0 :  20.0
#         (18, 19, 'V3') :  None :                     0.0 :  20.0
#         (18, 19, 'V4') :  None :                     0.0 :  20.0
#         (18, 19, 'V5') :  None :                     0.0 :  20.0
#         (18, 19, 'V6') :  None :                     0.0 :  20.0
#         (18, 20, 'V1') :  None :                     0.0 :  20.0
#         (18, 20, 'V2') :  None :     -0.9999999999999751 :  20.0
#         (18, 20, 'V3') :  None :                     0.0 :  20.0
#         (18, 20, 'V4') :  None :                     0.0 :  20.0
#         (18, 20, 'V5') :  None :                     0.0 :  20.0
#         (18, 20, 'V6') :  None :                     0.0 :  20.0
#         (18, 21, 'V1') :  None :                     0.0 :  20.0
#         (18, 21, 'V2') :  None :       -1.99999999999992 :  20.0
#         (18, 21, 'V3') :  None :                     0.0 :  20.0
#         (18, 21, 'V4') :  None :                     0.0 :  20.0
#         (18, 21, 'V5') :  None :                     0.0 :  20.0
#         (18, 21, 'V6') :  None :                     0.0 :  20.0
#         (19, 13, 'V1') :  None :                     0.0 :  20.0
#         (19, 13, 'V2') :  None :                     0.0 :  20.0
#         (19, 13, 'V3') :  None :                     0.0 :  20.0
#         (19, 13, 'V4') :  None :                     0.0 :  20.0
#         (19, 13, 'V5') :  None :                     0.0 :  20.0
#         (19, 13, 'V6') :  None :                     0.0 :  20.0
#         (19, 14, 'V1') :  None :                     0.0 :  20.0
#         (19, 14, 'V2') :  None :                     0.0 :  20.0
#         (19, 14, 'V3') :  None :                     0.0 :  20.0
#         (19, 14, 'V4') :  None :                     0.0 :  20.0
#         (19, 14, 'V5') :  None :                     0.0 :  20.0
#         (19, 14, 'V6') :  None :                     0.0 :  20.0
#         (19, 15, 'V1') :  None :                     0.0 :  20.0
#         (19, 15, 'V2') :  None :                     0.0 :  20.0
#         (19, 15, 'V3') :  None :                     0.0 :  20.0
#         (19, 15, 'V4') :  None :                     0.0 :  20.0
#         (19, 15, 'V5') :  None :                    -1.0 :  20.0
#         (19, 15, 'V6') :  None :                     0.0 :  20.0
#         (19, 16, 'V1') :  None :                     0.0 :  20.0
#         (19, 16, 'V2') :  None : -2.8754776337791554e-14 :  20.0
#         (19, 16, 'V3') :  None :                     0.0 :  20.0
#         (19, 16, 'V4') :  None :                     0.0 :  20.0
#         (19, 16, 'V5') :  None :                     0.0 :  20.0
#         (19, 16, 'V6') :  None :                     0.0 :  20.0
#         (19, 17, 'V1') :  None :                     0.0 :  20.0
#         (19, 17, 'V2') :  None :                     0.0 :  20.0
#         (19, 17, 'V3') :  None :                     0.0 :  20.0
#         (19, 17, 'V4') :  None :                     0.0 :  20.0
#         (19, 17, 'V5') :  None :                     0.0 :  20.0
#         (19, 17, 'V6') :  None :                     0.0 :  20.0
#         (19, 18, 'V1') :  None :                     0.0 :  20.0
#         (19, 18, 'V2') :  None :                     0.0 :  20.0
#         (19, 18, 'V3') :  None :                     0.0 :  20.0
#         (19, 18, 'V4') :  None :                     0.0 :  20.0
#         (19, 18, 'V5') :  None :                     0.0 :  20.0
#         (19, 18, 'V6') :  None :                     0.0 :  20.0
#         (19, 20, 'V1') :  None :                     0.0 :  20.0
#         (19, 20, 'V2') :  None :     -0.9999999999999751 :  20.0
#         (19, 20, 'V3') :  None :                     0.0 :  20.0
#         (19, 20, 'V4') :  None :                     0.0 :  20.0
#         (19, 20, 'V5') :  None :                     0.0 :  20.0
#         (19, 20, 'V6') :  None :                     0.0 :  20.0
#         (19, 21, 'V1') :  None :                     0.0 :  20.0
#         (19, 21, 'V2') :  None :     -1.9999999999998677 :  20.0
#         (19, 21, 'V3') :  None :                     0.0 :  20.0
#         (19, 21, 'V4') :  None :                     0.0 :  20.0
#         (19, 21, 'V5') :  None :                     0.0 :  20.0
#         (19, 21, 'V6') :  None :                     0.0 :  20.0
#         (20, 13, 'V1') :  None :                     0.0 :  20.0
#         (20, 13, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 13, 'V3') :  None :                     0.0 :  20.0
#         (20, 13, 'V4') :  None :                     0.0 :  20.0
#         (20, 13, 'V5') :  None :                     0.0 :  20.0
#         (20, 13, 'V6') :  None :                     0.0 :  20.0
#         (20, 14, 'V1') :  None :                     0.0 :  20.0
#         (20, 14, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 14, 'V3') :  None :                     0.0 :  20.0
#         (20, 14, 'V4') :  None :                     0.0 :  20.0
#         (20, 14, 'V5') :  None :                     0.0 :  20.0
#         (20, 14, 'V6') :  None :                     0.0 :  20.0
#         (20, 15, 'V1') :  None :                     0.0 :  20.0
#         (20, 15, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 15, 'V3') :  None :                     0.0 :  20.0
#         (20, 15, 'V4') :  None :  1.3211653993039208e-14 :  20.0
#         (20, 15, 'V5') :  None :                    -1.0 :  20.0
#         (20, 15, 'V6') :  None :                     0.0 :  20.0
#         (20, 16, 'V1') :  None :                     0.0 :  20.0
#         (20, 16, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 16, 'V3') :  None :                     0.0 :  20.0
#         (20, 16, 'V4') :  None :                     0.0 :  20.0
#         (20, 16, 'V5') :  None :                     0.0 :  20.0
#         (20, 16, 'V6') :  None :                     0.0 :  20.0
#         (20, 17, 'V1') :  None :                     0.0 :  20.0
#         (20, 17, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 17, 'V3') :  None :                     0.0 :  20.0
#         (20, 17, 'V4') :  None :                     0.0 :  20.0
#         (20, 17, 'V5') :  None :                     0.0 :  20.0
#         (20, 17, 'V6') :  None :                     0.0 :  20.0
#         (20, 18, 'V1') :  None :                     0.0 :  20.0
#         (20, 18, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 18, 'V3') :  None :                     0.0 :  20.0
#         (20, 18, 'V4') :  None :                     0.0 :  20.0
#         (20, 18, 'V5') :  None :                     0.0 :  20.0
#         (20, 18, 'V6') :  None :                     0.0 :  20.0
#         (20, 19, 'V1') :  None :                     0.0 :  20.0
#         (20, 19, 'V2') :  None :      0.9999999999999751 :  20.0
#         (20, 19, 'V3') :  None :                     0.0 :  20.0
#         (20, 19, 'V4') :  None :                     0.0 :  20.0
#         (20, 19, 'V5') :  None :                     0.0 :  20.0
#         (20, 19, 'V6') :  None :                     0.0 :  20.0
#         (20, 21, 'V1') :  None :                     0.0 :  20.0
#         (20, 21, 'V2') :  None :                    20.0 :  20.0
#         (20, 21, 'V3') :  None :                     0.0 :  20.0
#         (20, 21, 'V4') :  None :                     0.0 :  20.0
#         (20, 21, 'V5') :  None :                     0.0 :  20.0
#         (20, 21, 'V6') :  None :                     0.0 :  20.0
#         (21, 13, 'V1') :  None :                     0.0 :  20.0
#         (21, 13, 'V2') :  None :        1.99999999999992 :  20.0
#         (21, 13, 'V3') :  None :                     0.0 :  20.0
#         (21, 13, 'V4') :  None :                     0.0 :  20.0
#         (21, 13, 'V5') :  None :                     0.0 :  20.0
#         (21, 13, 'V6') :  None :                     0.0 :  20.0
#         (21, 14, 'V1') :  None :                     0.0 :  20.0
#         (21, 14, 'V2') :  None :        1.99999999999992 :  20.0
#         (21, 14, 'V3') :  None :                     0.0 :  20.0
#         (21, 14, 'V4') :  None :                     0.0 :  20.0
#         (21, 14, 'V5') :  None :                     0.0 :  20.0
#         (21, 14, 'V6') :  None :                     0.0 :  20.0
#         (21, 15, 'V1') :  None : -1.7680301667155618e-14 :  20.0
#         (21, 15, 'V2') :  None :        1.99999999999992 :  20.0
#         (21, 15, 'V3') :  None :  -9.325873406851315e-15 :  20.0
#         (21, 15, 'V4') :  None :                     0.0 :  20.0
#         (21, 15, 'V5') :  None :                    -1.0 :  20.0
#         (21, 15, 'V6') :  None :                     0.0 :  20.0
#         (21, 16, 'V1') :  None :  1.7680301667155618e-14 :  20.0
#         (21, 16, 'V2') :  None :        1.99999999999992 :  20.0
#         (21, 16, 'V3') :  None :                     0.0 :  20.0
#         (21, 16, 'V4') :  None :                     0.0 :  20.0
#         (21, 16, 'V5') :  None :                     0.0 :  20.0
#         (21, 16, 'V6') :  None :                     0.0 :  20.0
#         (21, 17, 'V1') :  None :                     0.0 :  20.0
#         (21, 17, 'V2') :  None :        1.99999999999992 :  20.0
#         (21, 17, 'V3') :  None :                     0.0 :  20.0
#         (21, 17, 'V4') :  None :                     0.0 :  20.0
#         (21, 17, 'V5') :  None :                     0.0 :  20.0
#         (21, 17, 'V6') :  None :                     0.0 :  20.0
#         (21, 18, 'V1') :  None :                     0.0 :  20.0
#         (21, 18, 'V2') :  None :        1.99999999999992 :  20.0
#         (21, 18, 'V3') :  None :                     0.0 :  20.0
#         (21, 18, 'V4') :  None :                     0.0 :  20.0
#         (21, 18, 'V5') :  None :                     0.0 :  20.0
#         (21, 18, 'V6') :  None :                     0.0 :  20.0
#         (21, 19, 'V1') :  None :                     0.0 :  20.0
#         (21, 19, 'V2') :  None :      1.9999999999999443 :  20.0
#         (21, 19, 'V3') :  None :                     0.0 :  20.0
#         (21, 19, 'V4') :  None :                     0.0 :  20.0
#         (21, 19, 'V5') :  None :                     0.0 :  20.0
#         (21, 19, 'V6') :  None :                     0.0 :  20.0
#         (21, 20, 'V1') :  None :                     0.0 :  20.0
#         (21, 20, 'V2') :  None :      0.9999999999999449 :  20.0
#         (21, 20, 'V3') :  None :  4.4686476741162544e-14 :  20.0
#         (21, 20, 'V4') :  None :                     0.0 :  20.0
#         (21, 20, 'V5') :  None :                     0.0 :  20.0
#         (21, 20, 'V6') :  None :                     0.0 :  20.0
#     restriccion_sale_vehiculo : Size=6
#         Key : Lower : Body               : Upper
#          V1 :   1.0 :                1.0 :   1.0
#          V2 :   1.0 : 0.9999999999999999 :   1.0
#          V3 :   1.0 : 1.0000000000000042 :   1.0
#          V4 :   1.0 : 0.9999999999999981 :   1.0
#          V5 :   1.0 :  1.000000000000003 :   1.0
#          V6 :   1.0 :                1.0 :   1.0
#     restriccion_entra_vehiculo : Size=6
#         Key : Lower : Body               : Upper
#          V1 :   1.0 :                1.0 :   1.0
#          V2 :   1.0 :                1.0 :   1.0
#          V3 :   1.0 : 0.9999999999999927 :   1.0
#          V4 :   1.0 : 0.9999999999999983 :   1.0
#          V5 :   1.0 :  1.000000000000003 :   1.0
#          V6 :   1.0 : 0.9999999999999988 :   1.0

# %%
vrp.exportar_rutas_a_csv("rutas_Case4.csv")
print("Costo total: $", vrp.model.obj(), "COP")
# Out:
# Rutas exportadas a rutas_Case4.csv
# Costo total: $ 258964.8166666666 COP
